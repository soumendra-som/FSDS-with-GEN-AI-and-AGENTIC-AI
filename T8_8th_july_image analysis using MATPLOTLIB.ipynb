# %%
import numpy as np
from numpy import*

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image  # PIL = python image library

# %%
img = Image.open(r'C:\Users\HP\Desktop\images.jpeg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=195x258>

# %%
type (img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img_arr=np.asarray(img)
img_arr
# Out:
# array([[[101, 147, 171],
#         [101, 147, 171],
#         [101, 147, 171],
#         ...,
#         [107, 153, 179],
#         [107, 153, 179],
#         [107, 153, 179]],
#
#        [[101, 147, 171],
#         [101, 147, 171],
#         [101, 147, 171],
#         ...,
#         [107, 153, 179],
#         [107, 153, 179],
#         [107, 153, 179]],
#
#        [[102, 148, 172],
#         [102, 148, 172],
#         [102, 148, 172],
#         ...,
#         [107, 153, 179],
#         [107, 153, 179],
#         [107, 153, 179]],
#
#        ...,
#
#        [[231, 224, 208],
#         [228, 222, 206],
#         [228, 221, 205],
#         ...,
#         [213, 204, 189],
#         [213, 204, 189],
#         [213, 203, 191]],
#
#        [[224, 218, 204],
#         [222, 219, 204],
#         [225, 219, 205],
#         ...,
#         [218, 210, 197],
#         [218, 210, 197],
#         [219, 211, 200]],
#
#        [[222, 218, 206],
#         [222, 218, 206],
#         [223, 219, 207],
# ...

# %%
type(img_arr)
# Out:
# numpy.ndarray

# %%
img_arr.shape
# Out:
# (258, 195, 3)

# %%
plt.imshow(img_arr)

# %%
rango_red=img_arr.copy()

# %%
rango_red==img_arr
# Out:
# array([[[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        ...,
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
# ...

# %%
rango_red.shape
# Out:
# (258, 195, 3)

# %%
plt.imshow(rango_red[:,:,0])

# %%
rango_red[:,:,0]
# Out:
# array([[101, 101, 101, ..., 107, 107, 107],
#        [101, 101, 101, ..., 107, 107, 107],
#        [102, 102, 102, ..., 107, 107, 107],
#        ...,
#        [231, 228, 228, ..., 213, 213, 213],
#        [224, 222, 225, ..., 218, 218, 219],
#        [222, 222, 223, ..., 217, 218, 218]], shape=(258, 195), dtype=uint8)

# %%
plt.imshow(rango_red[:,:,0],cmap='gray')

# %%
plt.imshow(rango_red[:,:,0],cmap='Blues')

# %%
plt.imshow(rango_red[:,:,0],cmap='Reds')

# %%
plt.imshow(rango_red[:,:,0],cmap='PuBu')

# %%
plt.imshow(rango_red[:,:,0],cmap='Grays')

# %%
plt.imshow(rango_red[:,:,1],cmap='grey')

# %%
plt.imshow(rango_red[:,:,2],cmap='grey')

# %%
rango_red[:,:,1]
# Out:
# array([[147, 147, 147, ..., 153, 153, 153],
#        [147, 147, 147, ..., 153, 153, 153],
#        [148, 148, 148, ..., 153, 153, 153],
#        ...,
#        [224, 222, 221, ..., 204, 204, 203],
#        [218, 219, 219, ..., 210, 210, 211],
#        [218, 218, 219, ..., 211, 212, 212]], shape=(258, 195), dtype=uint8)

# %%
rango_red[:,:,1] = 0
plt.imshow(rango_red)

# %%
rango_red[:,:,2] = 0
plt.imshow(rango_red)

# %%
rango_red[:,:,0] = 0
plt.imshow (rango_red)

# %%
plt.imshow(img_arr)

# %%
arr1 = np.array(img_arr)
arr1
# Out:
# array([[[101, 147, 171],
#         [101, 147, 171],
#         [101, 147, 171],
#         ...,
#         [107, 153, 179],
#         [107, 153, 179],
#         [107, 153, 179]],
#
#        [[101, 147, 171],
#         [101, 147, 171],
#         [101, 147, 171],
#         ...,
#         [107, 153, 179],
#         [107, 153, 179],
#         [107, 153, 179]],
#
#        [[102, 148, 172],
#         [102, 148, 172],
#         [102, 148, 172],
#         ...,
#         [107, 153, 179],
#         [107, 153, 179],
#         [107, 153, 179]],
#
#        ...,
#
#        [[231, 224, 208],
#         [228, 222, 206],
#         [228, 221, 205],
#         ...,
#         [213, 204, 189],
#         [213, 204, 189],
#         [213, 203, 191]],
#
#        [[224, 218, 204],
#         [222, 219, 204],
#         [225, 219, 205],
#         ...,
#         [218, 210, 197],
#         [218, 210, 197],
#         [219, 211, 200]],
#
#        [[222, 218, 206],
#         [222, 218, 206],
#         [223, 219, 207],
# ...

# %%
type(arr1)
# Out:
# numpy.ndarray

# %%
arr1.shape
# Out:
# (258, 195, 3)

# %%
plt.imshow(arr1)

# %%
rango_red1=arr1.copy()
rango_red1
# Out:
# array([[[101, 147, 171],
#         [101, 147, 171],
#         [101, 147, 171],
#         ...,
#         [107, 153, 179],
#         [107, 153, 179],
#         [107, 153, 179]],
#
#        [[101, 147, 171],
#         [101, 147, 171],
#         [101, 147, 171],
#         ...,
#         [107, 153, 179],
#         [107, 153, 179],
#         [107, 153, 179]],
#
#        [[102, 148, 172],
#         [102, 148, 172],
#         [102, 148, 172],
#         ...,
#         [107, 153, 179],
#         [107, 153, 179],
#         [107, 153, 179]],
#
#        ...,
#
#        [[231, 224, 208],
#         [228, 222, 206],
#         [228, 221, 205],
#         ...,
#         [213, 204, 189],
#         [213, 204, 189],
#         [213, 203, 191]],
#
#        [[224, 218, 204],
#         [222, 219, 204],
#         [225, 219, 205],
#         ...,
#         [218, 210, 197],
#         [218, 210, 197],
#         [219, 211, 200]],
#
#        [[222, 218, 206],
#         [222, 218, 206],
#         [223, 219, 207],
# ...

# %%
rango_red1[:,:,0]=0
plt.imshow(rango_red1)

# %%
rango_red1[:,:,1]= 0
plt.imshow(rango_red1)
